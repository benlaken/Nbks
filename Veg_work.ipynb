# %% [markdown]
# # Testing and code development for the MODIS vegetation project

# %% [markdown]
# Note there is a nice iPython notebook here with helpful info (http://nbviewer.ipython.org/github/profLewis/geogg122/blob/master/Chapter4_GDAL/advanced.ipynb and also http://nbviewer.ipython.org/gist/chryss/7638837 and http://nbviewer.ipython.org/github/profLewis/geogg122/blob/master/Chapter4_GDAL/GDAL_HDF.ipynb
#
# https://lpdaac.usgs.gov/products/modis_products_table/modis_overview Info on MODIS tiles

# %% [markdown]
# First step is to identify a list of the MODIS granules required, and download. This can easily be done with the NASA Reverb page.
#
# Then read the HDF data.
#
# Official note on the MODIS data:
#
# *MODIS LEVEL-2 AND HIGHER PRODUCTS AT THE Land Processes DAAC:
#
# Product quality assessment QA and validation are integral parts of the MODIS Land product generation process. The MODIS Land products have different data versions and levels of maturity reflecting algorithm refinement and the input data used in their production.  Please view technical information regarding product maturity and QA at: http://landweb.nascom.nasa.gov/cgi-bin/QA_WWW/newPage.cgi and product validation status at: http://landval.gsfc.nasa.gov/

# %%
import urllib2
import gdal
from mpl_toolkits.basemap import Basemap

# %%
def get_EVI(fname):
    g=gdal.Open(fname)
    if g is None:   # If the file isn't found, g will be none
        print "Problem opening file %s!" % f1 
    subdatasets = g.GetSubDatasets()
    meta = g.GetMetadata()   # Get the HDF metadata as a Dictionary
    print 'Reading Tile ',
    print 'Horizontal and Vertical tile No:',meta['HORIZONTALTILENUMBER'],meta['VERTICALTILENUMBER']
    #print 'Bounding coordinates- Lat (North South):',meta['NORTHBOUNDINGCOORDINATE'],'N ',meta['SOUTHBOUNDINGCOORDINATE'],'S'
    #print 'Bounding coordinates - Lon (East, West)',meta['EASTBOUNDINGCOORDINATE'],'E ',meta['WESTBOUNDINGCOORDINATE'],'W' 

    EVI = []
    gin = gdal.Open(subdatasets[1][0], gdal.GA_ReadOnly)
    if gin is None:
        raise IOError
    EVI = gin.ReadAsArray() 
    print "Read EVI"
    EVI = EVI * 10000.    # Scale factor from the hdf file for EVI
    aaa = np.where(EVI < -20000000)  # Remove ocean from EVI data (make an index)
    EVI[aaa] = None
    return EVI

# %%
# Test granules all from the same (first MODIS) time-point over West Africa
f1 = '/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf'
f2 = '/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v10.005.2006269200716.hdf'
f3 = '/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h22v08.005.2006269191345.hdf'
f4 = '/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h22v09.005.2006270035514.hdf'

g = gdal.Open(f1)

# %%
if g is None:   # If the file isn't found, g will be none
    print "Problem opening file %s!" % f1
else:
    #print "File opened %s" % f1

    
#metadata = g.GetMetadata_Dict()
#print(metadata['RANGEBEGINNINGDATE'], metadata['RANGEBEGINNINGTIME'])
#print '\n'
    
subdatasets = g.GetSubDatasets()
#for fname, name in subdatasets:
    print fname
    #print "\t", name
# Out:
# File opened /mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf
#
#
# HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days NDVI
# HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days EVI
# HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days VI Quality
# HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days red reflectance
# HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days NIR reflectance
# HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days blue reflectance
# HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days MIR reflectance
# HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days view zenith angle
# HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days sun zenith angle
# HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days relative azimuth angle
# HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days composite day of the year
# HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days pixel reliability

# %%
meta = g.GetMetadata()   # Get the HDF metadata as a Dictionary

print 'MODIS Tile Metadata'
print 'Horizontal and Vertical tile No:',meta['HORIZONTALTILENUMBER'],meta['VERTICALTILENUMBER']
#print 'Tile ID:',meta['TileID']
print 'Bounding coordinates- Lat (North South):',meta['NORTHBOUNDINGCOORDINATE'],'N ',meta['SOUTHBOUNDINGCOORDINATE'],'S'
print 'Bounding coordinates - Lon (East, West)',meta['EASTBOUNDINGCOORDINATE'],'E ',meta['WESTBOUNDINGCOORDINATE'],'W'
#print 'Grid rows, DOYs', meta['GLOBALGRIDROWS'],meta['DAYSOFYEAR']
#print 'Processed DOYs',meta['DAYSPROCESSED']

#print test.keys()
# Out:
# MODIS Tile Metadata
# Horizontal and Vertical tile No: 21 09
# Bounding coordinates- Lat (North South): -2.12661101602446e-15 N  -9.99999999910197 S
# Bounding coordinates - Lon (East, West) 40.6255263601016 E  29.9999999973059 W

# %% [markdown]
# ## Calculate the lat / lon points

# %% [markdown]
# Need to perform inverse mapping as described in section 4.2.6 of the MODIS user's guide for level 3 data at http://www.fao.org/fileadmin/templates/gfims/docs/MODIS_Fire_Users_Guide_2.4.pdf
#
# This will let me take the tile number, and row,column coordinates to calculate latitude and logitude in radians, from which I can perhaos eventually use as info when I plot the data

# %%
# Required constants 
R = 6371007.181                       # Radius (m) of an idealized sphere representing the Earth
T = 1111950.                          # Height (m) and width of each MODIS tile in a projection plane
xmin = -20015109.                     # Western limit (m) of projection plane
ymax = 10007555.                      # Northern limit (m) of projection plane
w = 231.65635826                      # Actual size (m) of a 250m MODIS sinusoidal gridcell (w = T/4800)
H = int(meta['HORIZONTALTILENUMBER']) # An integer from 0-35
V = int(meta['VERTICALTILENUMBER'])   # An integer from 0-17


# Inverse Mapping - Go from i(row),j(column) in a H,V MODIS tile coordinate to lon/lat in radians
radlat =0
radlon = 0

j = 2        # This will loop through all elements of j and i, but for now, just test with a corner 
i = 2        # Note there are 4800 rows and cells (total = 4800x4800)

print i,j,' ',w,' ',H,' ',V,' ',T,xmin,ymax, R, xmin,ymax

x = (j+0.5)*w + H * T + xmin       # j (column) to x (for lat) 
y = ymax - (i+0.5)*w - V * T       # i (row) to y (for lon)

radlat = y/R                           # This is the phi formulae from the MODIS users guide (pg 25)
radlon =  x/(R * np.cos(radlon))       # This is the lambda formalue from MODIS user guide (pg 25)

# n.b. Degrees = radians * (180./pi)
rconv = 180./np.pi

print 'Degrees Longitude:',radlon * rconv
print 'Degrees Latitude:',radlat * rconv
# Out:
# 2 2   231.65635826   21   9   1111950.0 -20015109.0 10007555.0 6371007.181 -20015109.0 10007555.0
# Degrees Longitude: 30.0051133714
# Degrees Latitude: -0.00516336730316

# %% [markdown]
# ## Extract MODIS data

# %%
subdatasets = g.GetSubDatasets()
for fname, name in subdatasets:
    print name
    print "\t", fname
# Out:
# [4800x4800] 250m 16 days NDVI MODIS_Grid_16DAY_250m_500m_VI (16-bit integer)
# 	HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days NDVI
# [4800x4800] 250m 16 days EVI MODIS_Grid_16DAY_250m_500m_VI (16-bit integer)
# 	HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days EVI
# [4800x4800] 250m 16 days VI Quality MODIS_Grid_16DAY_250m_500m_VI (16-bit unsigned integer)
# 	HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days VI Quality
# [4800x4800] 250m 16 days red reflectance MODIS_Grid_16DAY_250m_500m_VI (16-bit integer)
# 	HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days red reflectance
# [4800x4800] 250m 16 days NIR reflectance MODIS_Grid_16DAY_250m_500m_VI (16-bit integer)
# 	HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days NIR reflectance
# [4800x4800] 250m 16 days blue reflectance MODIS_Grid_16DAY_250m_500m_VI (16-bit integer)
# 	HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days blue reflectance
# [4800x4800] 250m 16 days MIR reflectance MODIS_Grid_16DAY_250m_500m_VI (16-bit integer)
# 	HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days MIR reflectance
# [4800x4800] 250m 16 days view zenith angle MODIS_Grid_16DAY_250m_500m_VI (16-bit integer)
# 	HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days view zenith angle
# [4800x4800] 250m 16 days sun zenith angle MODIS_Grid_16DAY_250m_500m_VI (16-bit integer)
# 	HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days sun zenith angle
# [4800x4800] 250m 16 days relative azimuth angle MODIS_Grid_16DAY_250m_500m_VI (16-bit integer)
# 	HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days relative azimuth angle
# [4800x4800] 250m 16 days composite day of the year MODIS_Grid_16DAY_250m_500m_VI (16-bit integer)
# 	HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days composite day of the year
# [4800x4800] 250m 16 days pixel reliability MODIS_Grid_16DAY_250m_500m_VI (8-bit integer)
# 	HDF4_EOS:EOS_GRID:"/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf":MODIS_Grid_16DAY_250m_500m_VI:250m 16 days pixel reliability

# %%
# Let's create a list with the selected layer names
selected_layers = [  "NDVI", "EVI", "VI_Qual" ]

# Initialise an empty dictionary
data = {}

for i, layer in enumerate ( selected_layers ):
    #print "Opening Layer %d: %s" % (i+1, filename )
    g = gdal.Open(subdatasets[i][0], gdal.GA_ReadOnly)
    
    if g is None:
        raise IOError
    data[layer] = g.ReadAsArray() 
    print "\t>>> Read %s" % layer
# Out:
# 	>>> Read NDVI
# 	>>> Read EVI
# 	>>> Read VI_Qual

# %% [markdown]
# ## EVI Data and plotting

# %%
type(data['EVI'])
EVI = data['EVI']*10000.  # Scale factor from the hdf file for EVI

# %%
#Remove (certain values eg. missing -30000000 = water?) 
# Or, the lowest valid value is 20000000
#aaa = np.where(EVI == -30000000)
aaa = np.where(EVI < -20000000)
EVI[aaa] = None

# %% [markdown]
# Negative values of NDVI (values approaching -1) correspond to water. Values close to zero (-0.1 to 0.1) generally correspond to barren areas of rock, sand, or snow. Lastly, low, positive values represent shrub and grassland (approximately 0.2 to 0.4), while high values indicate temperate and tropical rainforests (values approaching 1)

# %%
# Plot out the EVI data 
fig = plt.figure(figsize=(7, 7))
plt.imshow(EVI,interpolation='none',vmin=0.0,vmax=100000000.0,cmap=cm.gist_rainbow)
plt.title('MODIS EVI data test')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f6d04c37b90>

# %%
# THIS ISNT WORKING YET - WARNING!! ( projection is not correct, need to think on this...)

ll_lon = float(meta['WESTBOUNDINGCOORDINATE'])
ll_lat = float(meta['SOUTHBOUNDINGCOORDINATE'])
ur_lon = float(meta['EASTBOUNDINGCOORDINATE'])
ur_lat = float(meta['NORTHBOUNDINGCOORDINATE'])

m = Basemap(llcrnrlon=ll_lon,llcrnrlat=ll_lat,urcrnrlon=ur_lon,urcrnrlat=ur_lat,\
resolution='i',area_thresh=1.,projection='cyl')
m.imshow ( EVI, interpolation='none', origin='upper')
m.drawcoastlines(color='b',linewidth=1.0)
m.drawmapboundary() # draw a line around the map region
#m.drawparallels(numpy.arange(50, 55, 0.1),linewidth=0.2,labels=[1,0,0,0]) # draw parallels
#m.drawmeridians(numpy.arange(-140, -130, 0.3),linewidth=0.2,labels=[0,0,0,1]) # draw meridian
m.drawrivers()

# %% [markdown]
# ## Testing

# %%
f1 = '/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v08.005.2006269193705.hdf'
f2 = '/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v09.005.2006269200329.hdf'
f3 = '/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h21v10.005.2006269200716.hdf'
f4 = '/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h22v08.005.2006269191345.hdf'
f5 = '/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000049.h22v09.005.2006270035514.hdf'
f6 = '/mn/vann/metos-d1/blaken/MODIS_granules/MOD13Q1.A2000065.h22v10.005.2008238031837.hdf'

# %%
tile1 = get_EVI(f1)
tile2 = get_EVI(f2)
tile3 = get_EVI(f3)
tile4 = get_EVI(f4)
tile5 = get_EVI(f5)
tile6 = get_EVI(f6)
# Out:
# Reading Tile  Horizontal and Vertical tile No: 21 08
# Read EVI
# Reading Tile
#  Horizontal and Vertical tile No: 21 09
# Read EVI
# Reading Tile
#  Horizontal and Vertical tile No: 21 10
# Read EVI
# Reading Tile
#  Horizontal and Vertical tile No: 22 08
# Read EVI
# Reading Tile
#  Horizontal and Vertical tile No: 22 09
# Read EVI
# Reading Tile
#  Horizontal and Vertical tile No: 22 10
# Read EVI

# %%
#blank = np.zeros((4800,4800))
left=np.concatenate((tile1,tile2,tile3),axis=0)
right = np.concatenate((tile4,tile5,tile6),axis=0)
comb = np.concatenate((left,right),axis=1)

# %%
# Test Plot
fig = plt.figure(figsize=(10, 10))
plt.imshow(comb,interpolation='none',vmin=0.0,vmax=100000000.0,cmap=cm.RdYlGn)
plt.title('MODIS EVI data test - East Africa')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7fc2dd8b4488>

# %%
whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# Basemap    type        <class 'mpl_toolkits.basemap.Basemap'>
# comb       ndarray     14400x9600: 138240000 elems, type `float64`, 1105920000 bytes (1054 Mb)
# f1         str         /mn/vann/metos-d1/blaken/<...>v08.005.2006269193705.hdf
# f2         str         /mn/vann/metos-d1/blaken/<...>v09.005.2006269200329.hdf
# f3         str         /mn/vann/metos-d1/blaken/<...>v10.005.2006269200716.hdf
# f4         str         /mn/vann/metos-d1/blaken/<...>v08.005.2006269191345.hdf
# f5         str         /mn/vann/metos-d1/blaken/<...>v09.005.2006270035514.hdf
# f6         str         /mn/vann/metos-d1/blaken/<...>v10.005.2008238031837.hdf
# fig        Figure      Figure(800x800)
# gdal       module      <module 'gdal' from '/sit<...>nux-x86_64.egg/gdal.pyc'>
# get_EVI    function    <function get_EVI at 0x7fc4ec3ee8c0>
# left       ndarray     14400x4800: 69120000 elems, type `float64`, 552960000 bytes (527 Mb)
# right      ndarray     14400x4800: 69120000 elems, type `float64`, 552960000 bytes (527 Mb)
# tile1      ndarray     4800x4800: 23040000 elems, type `float64`, 184320000 bytes (175 Mb)
# tile2      ndarray     4800x4800: 23040000 elems, type `float64`, 184320000 bytes (175 Mb)
# tile3      ndarray     4800x4800: 23040000 elems, type `float64`, 184320000 bytes (175 Mb)
# tile4      ndarray     4800x4800: 23040000 elems, type `float64`, 184320000 bytes (175 Mb)
# tile5      ndarray     4800x4800: 23040000 elems, type `float64`, 184320000 bytes (175 Mb)
# tile6      ndarray     4800x4800: 23040000 elems, type `float64`, 184320000 bytes (175 Mb)
# urllib2    module      <module 'urllib2' from '/<...>b/python2.7/urllib2.pyc'>

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
           frames=200, interval=20, blit=True)

#plt.show()

anim.save('basic_animation.mp4', fps=30)
