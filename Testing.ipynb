# %% [raw]
# A test notebook for playing.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#pd.read_table("/Users/Ben/Work/Python/Output/Text/Daily_stats.txt",delim_whitespace=True,header=1)

# %%
x = np.linspace(0,10)
#print sin(x)
plt.xkcd()
plt.plot(sin(x),'r-',cos(x),'b-',(sin(x)+cos(x)),'g-')
plt.title('Test plot!')

# %%
# Out:
# ()
